# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifali111/Git-demo/blob/main/Research_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne
# Out:
# Collecting mne
#   Downloading mne-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.4)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from mne) (3.8.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from mne) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (24.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from mne) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.8.30)
# Downloading mne-1.8.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 45.2 MB/s eta 0:00:00
# Installing collected packages: mne
# Successfully installed mne-1.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import mne
from os.path import exists
from sklearn import preprocessing

# Define the number of healthy and MDD (Major Depressive Disorder) cases
H_num = 30  # Number of healthy cases
MDD_num = 34  # Number of MDD cases

# Initialize lists to store data and labels
v = []
Data = []
Label = []

# Define the categories for healthy and MDD cases
HorMDD = ['H', 'MDD']
# Define the eye states: EC (eyes closed), EO (eyes open), and TASK (P300 data)
eye_states = ['EC', 'EO', 'TASK']

# Directory where the .edf files are located)
directory = '/content/drive/My Drive/MDD-dataset/EDF_Data'  # Need to change to your own file path
#directory = '/Users/saifali/Desktop/Machine Learning/Research Project/Data/'


# Iterate over each category (healthy and MDD)
for x in HorMDD:
    # Set label based on category
    label_value = 0 if x == 'H' else 1
    num_subjects = H_num if x == 'H' else MDD_num

    # Process each subject
    for i in range(1, num_subjects + 1):
        # Iterate over each eye state
        for state in eye_states:
            # Construct the file path
            file = f"{directory}/{x} S{i} {state}.edf"

            # Check if the file exists
            if exists(file):
                # Read the EEG data from the .edf file
                data = mne.io.read_raw_edf(file, preload=True)
                raw_data = data.get_data()
                num_rows, num_cols = raw_data.shape

                # Ensure the number of rows is correct
                if num_rows > 19:
                    print(f"Extra channels in {file}: {num_rows}")
                    raw_data = np.delete(raw_data, 19, 0)

                # Ensure the data length is sufficient
                if raw_data.shape[1] < 61440:
                    print(f"File skipped due to insufficient length: {file}")
                    v.append(file)
                    continue

                # Trim or pad the data to a consistent length
                trimmed_data = raw_data[:, :61440]  # Trim if longer
                if trimmed_data.shape[1] < 61440:
                    padding = np.zeros((trimmed_data.shape[0], 61440 - trimmed_data.shape[1]))
                    trimmed_data = np.concatenate((trimmed_data, padding), axis=1)  # Pad if shorter

                # Append data and label
                Data.append(trimmed_data)
                Label.append(label_value)

                # Save the processed data and labels
                np.save(f"{directory}/Data/{x} S{i} {state}.npy", trimmed_data)
                np.save(f"{directory}/Label/{x} S{i} {state}.npy", label_value)
            else:
                print(f"File not found: {file}")

# Convert Data to an array with object dtype, if lengths vary
Data = np.array(Data, dtype=object)  # Handles any residual variations in shape
Label = np.asarray(Label)
# Out:
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S1 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S1 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S1 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 89855  =      0.000 ...   350.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S1 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S1 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S1 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S2 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S2 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S2 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S2 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S2 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S2 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S3 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S3 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S3 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78079  =      0.000 ...   304.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S3 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S3 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S3 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S4 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S4 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S4 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75519  =      0.000 ...   294.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S4 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S4 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S4 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S5 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S5 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S5 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79871  =      0.000 ...   311.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S5 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S5 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156671  =      0.000 ...   611.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S5 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S6 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S6 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S6 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S6 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S6 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156415  =      0.000 ...   610.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S6 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S7 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 91135  =      0.000 ...   355.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S7 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S7 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S7 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S7 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S7 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S8 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S8 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S8 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S8 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S8 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155903  =      0.000 ...   608.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S8 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S9 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S9 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S9 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S9 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S9 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 153855  =      0.000 ...   600.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S9 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S10 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 96255  =      0.000 ...   375.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S10 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S10 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S10 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S10 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S10 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S11 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S11 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S11 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S11 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S11 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S11 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/H S12 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S12 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S12 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S12 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S12 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S13 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S13 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S13 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S13 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S13 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S13 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S14 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S14 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S14 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 49663  =      0.000 ...   193.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S14 EO.edf: 22
# File skipped due to insufficient length: /content/drive/My Drive/MDD-dataset/EDF_Data/H S14 EO.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S14 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155391  =      0.000 ...   606.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S14 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S15 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S15 EC.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/H S15 EO.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S15 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S15 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S16 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 74751  =      0.000 ...   291.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S16 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S16 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S16 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S16 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162303  =      0.000 ...   633.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S16 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S17 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79103  =      0.000 ...   308.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S17 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S17 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S17 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S17 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S17 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/H S18 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S18 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S18 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S18 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155647  =      0.000 ...   607.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S18 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S19 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S19 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S19 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S19 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S19 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155647  =      0.000 ...   607.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S19 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S20 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78591  =      0.000 ...   306.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S20 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S20 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 81919  =      0.000 ...   319.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S20 EO.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/H S20 TASK.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S21 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S21 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S21 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78079  =      0.000 ...   304.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S21 EO.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/H S21 TASK.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S22 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S22 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S22 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S22 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S22 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154623  =      0.000 ...   603.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S22 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S23 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S23 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S23 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S23 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S23 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 158719  =      0.000 ...   619.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S23 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S24 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S24 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S24 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S24 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S24 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164863  =      0.000 ...   643.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S24 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S25 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S25 EC.edf: 20
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/H S25 EO.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S25 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164607  =      0.000 ...   642.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S25 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S26 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S26 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S26 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78079  =      0.000 ...   304.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S26 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S26 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156415  =      0.000 ...   610.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S26 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S27 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S27 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S27 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S27 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S27 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S27 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S28 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S28 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S28 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S28 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S28 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155391  =      0.000 ...   606.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S28 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S29 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S29 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S29 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S29 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S29 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S29 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S30 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S30 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S30 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S30 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/H S30 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/H S30 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S1 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S1 EC.edf: 20
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S1 EO.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S1 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161791  =      0.000 ...   631.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S1 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S2 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S2 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S2 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S2 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164863  =      0.000 ...   643.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S2 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S3 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 46079  =      0.000 ...   179.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S3 EC.edf: 20
# File skipped due to insufficient length: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S3 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S3 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S3 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S3 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S3 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S4 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S4 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S4 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S4 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S4 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S5 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S5 EC.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S5 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S5 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S5 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 157183  =      0.000 ...   613.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S5 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S6 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S6 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S6 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S6 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S6 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 163583  =      0.000 ...   638.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S6 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S7 EC.edf
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S7 EO.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S7 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162815  =      0.000 ...   635.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S7 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S8 EC.edf
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S8 EO.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S8 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155391  =      0.000 ...   606.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S8 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S9 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S9 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S9 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S9 EO.edf: 20
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S9 TASK.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S10 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S10 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S10 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S10 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S10 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 175615  =      0.000 ...   685.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S10 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S11 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S11 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S11 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S11 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 163071  =      0.000 ...   636.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S11 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S12 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S12 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 48383  =      0.000 ...   188.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S12 EO.edf: 20
# File skipped due to insufficient length: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S12 EO.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S12 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 166143  =      0.000 ...   648.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S12 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S13 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S13 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S13 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79615  =      0.000 ...   310.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S13 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S13 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S13 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S14 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S14 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S14 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S14 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S14 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162559  =      0.000 ...   634.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S14 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S15 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S15 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S15 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S15 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S15 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 160511  =      0.000 ...   626.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S15 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S16 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S16 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S16 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S16 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 163327  =      0.000 ...   637.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S16 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S17 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S17 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S17 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S17 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S17 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S17 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S18 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S18 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S18 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S18 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S18 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162815  =      0.000 ...   635.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S18 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S19 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S19 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S19 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S19 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S19 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162815  =      0.000 ...   635.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S19 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S20 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S20 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S20 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S20 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S20 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S20 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S21 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S21 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S21 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S21 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S21 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161791  =      0.000 ...   631.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S21 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S22 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S22 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S22 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S22 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S22 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164095  =      0.000 ...   640.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S22 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S23 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S23 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S23 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78591  =      0.000 ...   306.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S23 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S23 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161791  =      0.000 ...   631.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S23 TASK.edf: 22
# File not found: /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S24 EC.edf
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S24 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S24 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S24 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S24 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S25 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S25 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S25 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S25 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S25 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 160767  =      0.000 ...   627.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S25 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S26 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S26 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S26 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S26 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S26 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 163071  =      0.000 ...   636.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S26 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S27 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S27 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S27 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S27 EO.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S27 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S27 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S28 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S28 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S28 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S28 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S28 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161791  =      0.000 ...   631.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S28 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S29 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S29 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S29 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S29 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S29 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S29 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S30 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 61695  =      0.000 ...   240.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S30 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S30 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S30 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S30 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161023  =      0.000 ...   628.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S30 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S31 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S31 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S31 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S31 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S31 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S31 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S32 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S32 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S32 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S32 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S32 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 160767  =      0.000 ...   627.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S32 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S33 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S33 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S33 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75775  =      0.000 ...   295.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S33 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S33 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 168447  =      0.000 ...   657.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S33 TASK.edf: 22
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S34 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S34 EC.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S34 EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75775  =      0.000 ...   295.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S34 EO.edf: 20
# Extracting EDF parameters from /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S34 TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 168447  =      0.000 ...   657.996 secs...
# Extra channels in /content/drive/My Drive/MDD-dataset/EDF_Data/MDD S34 TASK.edf: 22

# %%
# Check for CUDA availability.
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
torch.cuda.empty_cache()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import TensorDataset, DataLoader


# Define constants for model configuration
output_directory = '/output'  # Directory to save output files
input_shape = [19, 61440]  # Input shape: 19 channels and 4-minute records
nb_classes = 2  # Number of classes: MDD or Healthy
nb_filters = 64  # Number of filters in Conv layers
verbose = True  # Verbose output during training
use_residual = True  # Use residual connections
use_bottleneck = True  # Use bottleneck layers
depth = 6  # Depth of the model
kernel_size = 41 - 1  # Kernel size for Conv layers
callbacks = None  # Callbacks for training
batch_size = 4  # Batch size for training
mini_batch_size = 32  # Mini-batch size for training
bottleneck_size = 57  # Bottleneck size
nb_epochs = 50  # Number of epochs for training
learning_rate = 0.01

# Define the Inception module
class InceptionModule(nn.Module):
    def __init__(self, in_channels, bottleneck_size, kernel_size, nb_filters):
        super(InceptionModule, self).__init__()
        self.use_bottleneck = use_bottleneck

        if self.use_bottleneck and in_channels > 1:
            self.bottleneck = nn.Conv1d(in_channels, bottleneck_size, kernel_size=1, padding='same', bias=False)
        else:
            self.bottleneck = nn.Identity()

        self.conv1 = nn.Conv1d(bottleneck_size, nb_filters, kernel_size=kernel_size // 2, padding='same', bias=False)
        self.conv2 = nn.Conv1d(bottleneck_size, nb_filters, kernel_size=kernel_size // 4, padding='same', bias=False)
        self.conv3 = nn.Conv1d(bottleneck_size, nb_filters, kernel_size=kernel_size // 8, padding='same', bias=False)
        self.maxpool = nn.MaxPool1d(kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv1d(bottleneck_size, nb_filters, kernel_size=1, padding='same', bias=False)

        self.batch_norm = nn.BatchNorm1d(nb_filters * 4)

    def forward(self, x):
        x = self.bottleneck(x)
        conv1 = self.conv1(x)
        conv2 = self.conv2(x)
        conv3 = self.conv3(x)
        maxpool = self.conv4(self.maxpool(x))
        out = torch.cat([conv1, conv2, conv3, maxpool], dim=1)
        out = self.batch_norm(out)
        return F.relu(out)

# Define the shortcut layer for residual connections
class ShortcutLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ShortcutLayer, self).__init__()
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size=1, padding='same', bias=False)
        self.batch_norm = nn.BatchNorm1d(out_channels)

    def forward(self, input_tensor, out_tensor):
        shortcut = self.conv(input_tensor)
        shortcut = self.batch_norm(shortcut)
        out = shortcut + out_tensor
        return F.relu(out)

# Build the model
class InceptionModel(nn.Module):
    def __init__(self, input_shape, nb_classes, depth, bottleneck_size, kernel_size, nb_filters):
        super(InceptionModel, self).__init__()
        self.depth = depth
        self.use_residual = use_residual
        self.inception_modules = nn.ModuleList()
        in_channels = input_shape[0]

        for d in range(depth):
            self.inception_modules.append(InceptionModule(in_channels, bottleneck_size, kernel_size, nb_filters))
            in_channels = nb_filters * 4

        self.gap = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(in_channels, nb_classes)

    def forward(self, x):
        input_res = x
        for d in range(self.depth):
            x = self.inception_modules[d](x)
            if self.use_residual and d % 3 == 2:
                x = ShortcutLayer(input_res.size(1), x.size(1)).to(x.device)(input_res, x)
                input_res = x

        x = self.gap(x).squeeze(-1)
        x = self.fc(x)
        return F.log_softmax(x, dim=1)

# Move the model to the GPU
model = InceptionModel(input_shape, nb_classes, depth, bottleneck_size, kernel_size, nb_filters).to(device)

# Print the model summary
print(model)

# Define the optimizer and loss function
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, nesterov=True)
criterion = nn.MSELoss()

# Assuming X_train and y_train are numpy arrays
X_train = np.random.rand(100, *input_shape).astype(np.float32)
y_train = np.random.randint(0, 2, size=(100,)).astype(np.int64)

# Create DataLoader
train_dataset = TensorDataset(torch.tensor(X_train), torch.tensor(y_train))
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Training loop
for epoch in range(nb_epochs):
    model.train()
    epoch_loss = 0.0
    correct = 0
    total = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, F.one_hot(y_batch, num_classes=nb_classes).float())
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

        # accuracy calculator
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)

    # Calculate accuracy
    accuracy = (correct / total) * 100

    if epoch % 10 == 0:
        print(f"Epoch {epoch}/{nb_epochs}, Loss: {epoch_loss / len(train_loader)}, Accuracy :{accuracy}")
# Out:
# InceptionModel(
#   (inception_modules): ModuleList(
#     (0): InceptionModule(
#       (bottleneck): Conv1d(19, 57, kernel_size=(1,), stride=(1,), padding=same, bias=False)
#       (conv1): Conv1d(57, 64, kernel_size=(20,), stride=(1,), padding=same, bias=False)
#       (conv2): Conv1d(57, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#       (conv3): Conv1d(57, 64, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#       (maxpool): MaxPool1d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (conv4): Conv1d(57, 64, kernel_size=(1,), stride=(1,), padding=same, bias=False)
#       (batch_norm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1-5): 5 x InceptionModule(
#       (bottleneck): Conv1d(256, 57, kernel_size=(1,), stride=(1,), padding=same, bias=False)
#       (conv1): Conv1d(57, 64, kernel_size=(20,), stride=(1,), padding=same, bias=False)
#       (conv2): Conv1d(57, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#       (conv3): Conv1d(57, 64, kernel_size=(5,), stride=(1,), padding=same, bias=False)
#       (maxpool): MaxPool1d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (conv4): Conv1d(57, 64, kernel_size=(1,), stride=(1,), padding=same, bias=False)
#       (batch_norm): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (gap): AdaptiveAvgPool1d(output_size=1)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1036.)
#   return F.conv1d(
# Epoch 0/50, Loss: 883.3574112272263
# Epoch 10/50, Loss: 5.203097133636475
# Epoch 20/50, Loss: 3.338097958564758
# Epoch 30/50, Loss: 3.1272587680816653
# Epoch 40/50, Loss: 2.178376097679138
